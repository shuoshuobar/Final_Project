# %% [markdown]
# # Checklist:
# ## 1. Missing Data
# ## 2. Regex Structure
# ## 3. Add the word "restaurant" to "name"
# ## 4. Paginate: Different Pages

# %%
# !pip install playwright
# Out:
# Requirement already satisfied: playwright in /Users/wangyushuo/.pyenv/versions/3.11.8/lib/python3.11/site-packages (1.48.0)
# Requirement already satisfied: greenlet==3.1.1 in /Users/wangyushuo/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from playwright) (3.1.1)
# Requirement already satisfied: pyee==12.0.0 in /Users/wangyushuo/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from playwright) (12.0.0)
# Requirement already satisfied: typing-extensions in /Users/wangyushuo/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from pyee==12.0.0->playwright) (4.12.2)
#
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
# !playwright install

# %%
from playwright.async_api import async_playwright

# %%
playwright = await async_playwright().start()
browser = await playwright.chromium.launch(headless=False)
page = await browser.new_page()

# %%
await page.goto("https://www.fantuanorder.com/")
# Out:
# <Response url='https://www.fantuanorder.com/' request=<Request url='https://www.fantuanorder.com/' method='GET'>>

# %%
html = await page.content()
html
# Out:
# '<!DOCTYPE html><html lang="en-US"><head><meta charset="utf-8"><meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1, viewport-fit=cover, user-scalable=no"><link rel="stylesheet" href="/_next/static/css/5f63d57e99583d9a.css" data-precedence="next"><link rel="stylesheet" href="/_next/static/css/7b748536bdfba672.css" data-precedence="next"><link rel="stylesheet" href="/_next/static/css/7b0a05b0da6251f4.css" data-precedence="next"><link rel="stylesheet" href="/_next/static/css/c07160c77dcc9158.css" data-precedence="next"><link rel="stylesheet" href="/_next/static/css/f3f881c994d88f28.css" data-precedence="next"><link rel="stylesheet" href="/_next/static/css/ff5c03ee2f6ef765.css" data-precedence="next"><link rel="stylesheet" href="/_next/static/css/a83745a985541833.css" data-precedence="next"><link rel="stylesheet" href="/_next/static/css/5c4223b0b5000343.css" data-precedence="next"><link rel="stylesheet" href="/_next/static/css/ea2fe16a9984208f.css" data-precedence="next"><link rel="stylesheet" href="/_next/static/css/112f92cbf98937a3.css" data-precedence="next"><link rel="stylesheet" href="/_next/static/css/9b7b6943283fdd9b.css" data-precedence="next"><link rel="stylesheet" href="/_next/static/css/400c90e1c1d5c1ba.css" data-precedence="next"><link rel="stylesheet" href="/_next/static/css/857995bf84d7b0a7.css" data-precedence="next"><link rel="stylesheet" href="/_next/static/css/e326b3b510cc7fcd.css" data-precedence="next"><link rel="stylesheet" href="/_next/static/css/4987f87b59db119e.css" data-precedence="next"><link rel="stylesheet" href="/_next/static/css/f77d127d92590507.css" data-precedence="next"><link rel="stylesheet" href="/_next/static/css/9f761712a90aba7a.css" data-precedence="next"><link rel="stylesheet" href="/_next/static/css/d8dc55a5330ee10f.css" data-precedence="next"><link rel="stylesheet" href="/_next/static/css/87a251f459ffd671.css" data-precedence="next"><link rel="stylesheet" href="/_next/static/css/f1eec9dd751a7c07.css" data-precedence="next"><link rel="stylesheet" href="/_next/static/css/2d291b26638e14e5.css" data-precedence="next"><link rel="stylesheet" href="/_next/static/css/c3727f675ac02cc8.css" data-precedence="next"><link rel="stylesheet" href="/_next/static/css/7681b3973147e49e.css" data-precedence="next"><link rel="stylesheet" href="/_next/static/css/1d3f60ae4749c565.css" data-precedence="next"><link rel="stylesheet" href="/_next/static/css/d7e260c9bba5db7e.css" data-precedence="next"><link rel="stylesheet" href="/_next/static/css/4e239fc6f8cf1c5c.css" data-precedence="next"><link rel="stylesheet" href="/_next/static/css/e4ef9866ef440fd0.css" data-precedence="next"><link rel="stylesheet" href="/_next/static/css/1a6795a48d911612.css" data-precedence="next"><link rel="stylesheet" href="/_next/static/css/4bb25a41ca7a5786.css" data-precedence="next"><link rel="stylesheet" href="/_next/static/css/28500bf645320eef.css" data-precedence="next"><link rel="stylesheet" href="/_next/static/css/c66d8696a2b70158.css" data-precedence="next"><link rel="stylesheet" href="/_next/static/css/cded5e6ac06b6268.css" data-precedence="next"><link rel="preload" as="script" fetchpriority="low" href="/_next/static/chunks/webpack-593e41716627e8c1.js"><script src="/_next/static/chunks/fd9d1056-9861bb2cb6e58e1d.js" async=""></script><script src="/_next/static/chunks/396464d2-ac703511d077ac0c.js" async=""></script><script src="/_next/static/chunks/1564-60f5464f14d936a8.js" async=""></script><script src="/_next/static/chunks/main-app-5d4cfe3b52d63439.js" async=""></script><script src="/_next/static/chunks/3045-0bd037d7c60b342c.js" async=""></script><script src="/_next/static/chunks/9c423f98-49cbad670741d834.js" async=""></script><script src="/_next/static/chunks/588-93cbf40024b1650d.js" async=""></script><script src="/_next/static/chunks/1100-aa860d8afd32b89d.js" async=""></script><script src="/_next/static/chunks/3640-0e3ddc5eae97f366.js" async=""></script><script src="/_next/static/chunks/3492-4cdcea ...

# %%
# Extract restaurant elements
# Wait for the page content to load
await page.wait_for_selector("#scrollableDiv")

# Continuously click "Load More" button until all content is loaded
while True:
    try:
        load_more_button = await page.query_selector(".loadMore .btn")
        if load_more_button:
            #print("Clicking 'Load More' button...")
            await load_more_button.click()
            await page.wait_for_timeout(2000)  # Wait for new content to load
        else:
            break  # No "Load More" button found
    except Exception as e:
        print("No more content to load or an error occurred:", e)
        break

# Extract restaurant elements
restaurant_elements = await page.query_selector_all(".ant-list-item")

restaurant_data = []

# Iterate over each restaurant and extract details
for restaurant in restaurant_elements:
    # Full text for raw processing later
    raw_name_element = await restaurant.query_selector(".name")
    raw_name = await raw_name_element.inner_text() if raw_name_element else "No name"

    # Coupon or offer
    coupon_element = await restaurant.query_selector(".sign")
    coupon = await coupon_element.inner_text() if coupon_element else "No Coupon"

    # Rating
    rate_element = await restaurant.query_selector(".rate")
    rating = await rate_element.inner_text() if rate_element else "No Rating"

    # Delivery info
    state_label_element = await restaurant.query_selector(".stateLabel")
    delivery_info = await state_label_element.inner_text() if state_label_element else "No delivery info"

    # Append raw data to the list
    restaurant_data.append({
        "raw_name": raw_name,
        "Coupon": coupon,
        "Rating": rating,
        "raw_delivery_info": delivery_info,
    })

    # Print raw extracted information 
    print(f"Raw Name: {raw_name}")
    print(f"Coupon: {coupon}")
    print(f"Rating: {rating}")
    print(f"Raw Delivery Info: {delivery_info}")
    print("-" * 80)
# Out:
# Raw Name: $13 OFF | Shanghai Time (Midtown)
# Coupon: $11.5 off $40 rookie coupon
# Rating: 4.7
# Raw Delivery Info: Over 73min • Delivery $4.49 • average $23 • Chinese
# --------------------------------------------------------------------------------
# Raw Name: Tasty Hand-Pulled Noodles 2 (Midtown)
# Coupon: $11.5 off $40 rookie coupon
# Rating: 4.7
# Raw Delivery Info: 49-59min • Delivery $2.99 • average $25 • Chinese / Noodles
# --------------------------------------------------------------------------------
# Raw Name: $13 OFF | Hutaoli (Midtown)
# Coupon: Specials 100% off
# Rating: 4.4
# Raw Delivery Info: 62-72min • Delivery $4.49 • Chinese / Spicy
# --------------------------------------------------------------------------------
# Raw Name: HEYTEA (Broadway)
# Coupon: $11.5 off $40 rookie coupon
# Rating: 4.8
# Raw Delivery Info: 60-70min • Delivery $4.49 • average $9 • Bubble Tea
# --------------------------------------------------------------------------------
# Raw Name: $13 OFF | The Best Sichuan (Midtown)
# Coupon: Specials 100% off
# Rating: 4.7
# Raw Delivery Info: 42-52min • Delivery $4.49 • average $24 • Chinese / Spicy
# --------------------------------------------------------------------------------
# Raw Name: $5 OFF | Bibble & Sip (Midtown)
# Coupon: $11.5 off $40 rookie coupon
# Rating: 4.5
# Raw Delivery Info: 51-61min • Delivery $2.99 • average $15 • Cake / Dessert
# --------------------------------------------------------------------------------
# Raw Name: $13 OFF | Liu's MalaTang (Midtown)
# Coupon: Specials 100% off
# Rating: 4.8
# Raw Delivery Info: 47-57min • Delivery $2.99 • average $16 • Chinese / Spicy
# --------------------------------------------------------------------------------
# Raw Name: $13 OFF | MomenTea Kitchen (Times Square)
# Coupon: $11.5 off $40 rookie coupon
# Rating: 4.6
# Raw Delivery Info: 43-53min • Delivery $4.49 • average $20 • Japanese
# --------------------------------------------------------------------------------
# Raw Name: $7 OFF | Möge Tee (Downtown)
# Coupon: $7 off $15
# Rating: 4.7
# Raw Delivery Info: Over 73min • Delivery $4.99 • average $8 • Bubble Tea
# --------------------------------------------------------------------------------
# Raw Name: Four Four South Village (Midtown)
# Coupon: $11.5 off $40 rookie coupon
# Rating: 4.6
# Raw Delivery Info: 56-66min • Delivery $2.99 • average $24 • Chinese / Taiwanese
# --------------------------------------------------------------------------------
# Raw Name: $13 OFF | OBAO Hell's kitchen (Hell's kitchen )
# Coupon: $11.5 off $40 rookie coupon
# Rating: 4.7
# Raw Delivery Info: 39-49min • Delivery $2.99 • average $31 • Fast Food / Chinese
# --------------------------------------------------------------------------------
# Raw Name: 50% OFF Specials | $10 OFF | Dim Sum Palace (Midtown)
# Coupon: $11.5 off $40 rookie coupon
# Rating: 4.4
# Raw Delivery Info: 36-46min • Delivery $2.99 • average $24 • Chinese / Cantonese
# --------------------------------------------------------------------------------
# Raw Name: $7 OFF | Bites of Xi‘an (Midtown)
# Coupon: $11.5 off $40 rookie coupon
# Rating: 4.9
# Raw Delivery Info: 50-60min • Delivery $2.99 • average $17 • Chinese / Noodles
# --------------------------------------------------------------------------------
# Raw Name: $13 OFF | Thai Time (Midtown)
# Coupon: $11.5 off $40 rookie coupon
# Rating: 4.6
# Raw Delivery Info: Over 73min • Delivery $4.99 • average $19 • Asian / Thai
# --------------------------------------------------------------------------------
# Raw Name: I'Milky
# Coupon: $11.5 off $40 rookie coupon
# Rating: 5.0
# Raw Delivery Info: Over 73min • Delivery $4.49 • average $18 • Bubble Tea / Cafe
# --------------------------------------------------------------------------------
# Raw Name: $10 OFF | Teriyaki R Us (Midtown)
# Coupon: $11.5 off $40 rookie coupon
# Rating: 4.4
# Raw Delivery Info: 55-65min • Delivery $2.99 • average $17 • Chinese / BBQ
# --------------------------------------------------------------------------------
# Raw Name: $7 OFF | Bites of Xi‘an 38th (Midtown)
# Coupon: $11.5 off $40 rookie coupon
# Rating: 4.3
# Raw Delivery Info: 60-70min • Delivery $4.49 • average $17 • Chinese / Noodles
# --------------------------------------------------------------------------------
# Raw Name: $13 OFF | Oohu Sezchun & Canton Cuisines (Midtown)
# Coupon: $11.5 off $40 rookie coupon
# Rating: 4.5
# Raw Delivery Info: 54-64min • Delivery $4.49 • average $21 • Chinese / Spicy
# --------------------------------------------------------------------------------
# Raw Name: $13 OFF | Jian Bing Man (Koreatown)
# Coupon: $11.5 off $40 rookie coupon
# Rating: 4.6
# Raw Delivery Info: Over 73min • Delivery $4.49 • average $19 • Fast Food / Breakfast
# --------------------------------------------------------------------------------
# Raw Name: Bubble Bae (Midtown)
# Coupon: $11.5 off $40 rookie coupon
# Rating: 4.8
# Raw Delivery Info: 50-60min • Delivery $2.99 • average $26 • Fast Food / Burgers
# --------------------------------------------------------------------------------
# Raw Name: $13 OFF | Big Wong (Midtown)
# Coupon: $11.5 off $40 rookie coupon
# Rating: 4.4
# Raw Delivery Info: 60-70min • Delivery $2.99 • average $23 • Chinese / Cantonese
# --------------------------------------------------------------------------------
# Raw Name: Lady M (Broadway)
# Coupon: $11.5 off $40 rookie coupon
# Rating: 4.5
# Raw Delivery Info: Over 73min • Delivery $4.99 • average $19 • Cake / Dessert
# --------------------------------------------------------------------------------
# Raw Name: DimSum Garden (Midtown)
# Coupon: Specials 100% off
# Rating: 4.7
# Raw Delivery Info: Over 73min • Delivery $4.49 • average $43 • Dessert / Chinese
# --------------------------------------------------------------------------------
# Raw Name: $13 OFF | Lunar (Midtown)
# Coupon: $11.5 off $40 rookie coupon
# Rating: 4.2
# Raw Delivery Info: 61-71min • Delivery $4.49 • average $33 • Chinese / Spicy
# --------------------------------------------------------------------------------
# Raw Name: Hawa Smoothies & Bubble Tea (Midtown)
# Coupon: $11.5 off $40 rookie coupon
# Rating: 4.7
# Raw Delivery Info: 36-46min • Delivery $2.99 • Bubble Tea / Ice Cream
# --------------------------------------------------------------------------------
# Raw Name: $13 OFF | Chef Yu (Midtown)
# Coupon: $11.5 off $40 rookie coupon
# Rating: 4.0
# Raw Delivery Info: 51-61min • Delivery $4.49 • average $16 • Chinese / Spicy
# --------------------------------------------------------------------------------
# Raw Name: $12 OFF | T.K.K. Fried Chicken
# Coupon: $11.5 off $40 rookie coupon
# Rating: 4.4
# Raw Delivery Info: Over 73min • Delivery $4.99 • average $19 • Fast Food / Chinese
# --------------------------------------------------------------------------------
# Raw Name: $7 OFF | Bites of Xi‘an (32 st)
# Coupon: Specials 50% off
# Rating: 4.6
# Raw Delivery Info: 63-73min • Delivery $4.49 • average $19 • Chinese / Noodles
# --------------------------------------------------------------------------------
# Raw Name: $12 OFF | Grand Sichuan Eastern (Midtown)
# Coupon: Specials 100% off
# Rating: 4.6
# Raw Delivery Info: 45-55min • Delivery $4.49 • average $27 • Chinese / Spicy
# --------------------------------------------------------------------------------
# Raw Name: Shinjuku Ramen (Midtown)
# Coupon: $11.5 off $40 rookie coupon
# Rating: 4.9
# Raw Delivery Info: 53-63min • Delivery $2.99 • average $34 • Japanese / Noodles
# --------------------------------------------------------------------------------
# Raw Name: $10 OFF | Hunan Village
# Coupon: $11.5 off $40 rookie coupon
# Rating: 4.3
# Raw Delivery Info: 29-39min • Delivery $4.49 • average $24 • Chinese / Spicy
# --------------------------------------------------------------------------------
# Raw Name: $9 OFF | Chef Huang (Midtown)
# Coupon: $11.5 off $40 rookie coupon
# Rating: 4.1
# Raw Delivery Info: Over 73min • Delivery $4.99 • average $50 • Chinese
# --------------------------------------------------------------------------------
# Raw Name: $13 OFF | Sanmiwago & Botbar (Midtown)
# Coupon: $11.5 off $40 rookie coupon
# Rating: 4.3
# Raw Delivery Info: 56-66min • Delivery $2.99 • average $19 • Chinese / Cantonese
# --------------------------------------------------------------------------------
# Raw Name: $13 OFF | Appas Pizza
# Coupon: $11.5 off $40 rookie coupon
# Rating: 4.7
# Raw Delivery Info: Over 73min • Delivery $4.99 • average $20 • Korean / Fast Food
# --------------------------------------------------------------------------------
# Raw Name: $12 OFF | Taiwan 101 Steak house-Times Square (Midtown)
# Coupon: $11.5 off $40 rookie coupon
# Rating: No Rating
# Raw Delivery Info: 37-47min • Delivery $2.99 • average $18 • Chinese / Taiwanese
# --------------------------------------------------------------------------------
# Raw Name: $12 OFF | Ho Ho Te (Midtown)
# Coupon: $11.5 off $40 rookie coupon
# Rating: 4.6
# Raw Delivery Info: Over 73min • Delivery $2.99 • average $18 • Bubble Tea
# --------------------------------------------------------------------------------
# Raw Name: $13 OFF | Pelicana Chicken Hell’s Kitchen
# Coupon: $11.5 off $40 rookie coupon
# Rating: 5.0
# Raw Delivery Info: 51-61min • Delivery $2.99 • average $14 • Chickens
# --------------------------------------------------------------------------------
# Raw Name: Grace Street Coffee & Desserts (Midtown)
# Coupon: $11.5 off $40 rookie coupon
# Rating: 4.6
# Raw Delivery Info: Over 73min • Delivery $4.49 • average $17 • Bubble Tea / Cafe
# --------------------------------------------------------------------------------
# Raw Name: $13 OFF | Pelicana Chicken Koreatown
# Coupon: $11.5 off $40 rookie coupon
# Rating: No Rating
# Raw Delivery Info: 63-73min • Delivery $4.49 • average $17 • Korean / Chickens
# --------------------------------------------------------------------------------
# Raw Name: $10 OFF | Xi'an Cuisine (Mid town)
# Coupon: $11.5 off $40 rookie coupon
# Rating: 4.2
# Raw Delivery Info: 61-71min • Delivery $4.49 • average $19 • Fast Food / Breakfast
# --------------------------------------------------------------------------------
# Raw Name: 50% Off | Hua Cheng Restaurant (Midtown)
# Coupon: $11.5 off $40 rookie coupon
# Rating: 5.0
# Raw Delivery Info: 57-67min • Delivery $4.49 • Chinese / Spicy
# --------------------------------------------------------------------------------
# Raw Name: $10 OFF | Szechuan Gourmet (Midtown)
# Coupon: $11.5 off $40 rookie coupon
# Rating: 4.3
# Raw Delivery Info: 60-70min • Delivery $4.49 • average $43 • Chinese / Spicy
# --------------------------------------------------------------------------------
# Raw Name: $13 OFF | DAO Dim Sum & Chinese Cuisine (Midtown)
# Coupon: $11.5 off $40 rookie coupon
# Rating: 4.6
# Raw Delivery Info: Over 73min • Delivery $4.99 • average $25 • Chinese
# --------------------------------------------------------------------------------
# Raw Name: $6 OFF | Kyuramen - Times Square (Midtown)
# Coupon: $11.5 off $40 rookie coupon
# Rating: 4.5
# Raw Delivery Info: 56-66min • Delivery $2.99 • average $25 • Japanese / Noodles
# --------------------------------------------------------------------------------
# Raw Name: $13 OFF | Tipsy Shanghai (3rd Ave)
# Coupon: Specials 100% off
# Rating: 4.1
# Raw Delivery Info: 50-60min • Delivery $4.49 • average $27 • Chinese
# --------------------------------------------------------------------------------
# Raw Name: 70%off | Cozy Rice (Midtown)
# Coupon: $11.5 off $40 rookie coupon
# Rating: 4.8
# Raw Delivery Info: 61-71min • Delivery $4.49 • Fast Food / Breakfast
# --------------------------------------------------------------------------------
# Raw Name: $13 OFF | Kitchen Paradise (Midtown)
# Coupon: Specials 87% off
# Rating: No Rating
# Raw Delivery Info: 56-66min • Delivery $2.99 • average $15 • Chinese / Spicy
# --------------------------------------------------------------------------------
# Raw Name: $9 OFF | 3 Chick
# Coupon: Specials 80% off
# Rating: 5.0
# Raw Delivery Info: 58-68min • Delivery $2.99 • average $51 • Japanese / Fast Food
# --------------------------------------------------------------------------------
# Raw Name: Wednesday BOGO | Biao Sugar (Midtown)
# Coupon: $11.5 off $40 rookie coupon
# Rating: 4.4
# Raw Delivery Info: 63-73min • Delivery $4.49 • Bubble Tea
# --------------------------------------------------------------------------------
# Raw Name: $13 OFF | Poke Bowl (Midtown)
# Coupon: Specials 100% off
# Rating: 4.4
# Raw Delivery Info: Over 73min • Delivery $4.49 • average $16 • Fast Food / American
# --------------------------------------------------------------------------------
# Raw Name: $13 OFF | Noddles Boss (East village)
# Coupon: $11.5 off $40 rookie coupon
# Rating: No Rating
# Raw Delivery Info: Over 73min • Delivery $4.99 • average $16 • Fast Food / Breakfast
# --------------------------------------------------------------------------------
# Raw Name: $12 OFF | LENOXTHAI (Uptown)
# Coupon: $11.5 off $40 rookie coupon
# Rating: 4.3
# Raw Delivery Info: 57-67min • Delivery $2.99 • average $28 • Asian / Thai
# --------------------------------------------------------------------------------
# Raw Name: $10 OFF | 川云涧 (Midtown)
# Coupon: $11.5 off $40 rookie coupon
# Rating: 4.0
# Raw Delivery Info: 57-67min • Delivery $4.49 • average $27 • Chinese / Spicy
# --------------------------------------------------------------------------------
# Raw Name: $10 OFF | Nanxiang Express (Hell's Kitchen)
# Coupon: $11.5 off $40 rookie coupon
# Rating: 4.5
# Raw Delivery Info: 51-61min • Delivery $2.99 • average $26 • Chinese / Alcohol
# --------------------------------------------------------------------------------
# Raw Name: $12 OFF | Kung Fu Tea (Midtown)
# Coupon: $11.5 off $40 rookie coupon
# Rating: No Rating
# Raw Delivery Info: Over 73min • Delivery $4.99 • average $10 • Bubble Tea / Cafe
# --------------------------------------------------------------------------------
# Raw Name: $10 OFF | Abiko Curry (Midtown)
# Coupon: $11.5 off $40 rookie coupon
# Rating: 4.2
# Raw Delivery Info: Over 73min • Delivery $4.99 • average $23 • Japanese
# --------------------------------------------------------------------------------
# Raw Name: $4 OFF | Kung Fu Tea(NYU)
# Coupon: $11.5 off $40 rookie coupon
# Rating: 4.7
# Raw Delivery Info: Over 73min • Delivery $4.99 • average $8 • Bubble Tea / Cafe
# --------------------------------------------------------------------------------
# Raw Name: Lady M (Rockefeller Plaza)
# Coupon: $11.5 off $40 rookie coupon
# Rating: 5.0
# Raw Delivery Info: 25-40min • Delivery $2.99 • average $20 • Cake / Dessert
# --------------------------------------------------------------------------------
# Raw Name: 35% OFF | Jurin Sushi Omakse (Midtown)
# Coupon: $11.5 off $40 rookie coupon
# Rating: 4.3
# Raw Delivery Info: 49-59min • Delivery $4.49 • average $54 • Japanese
# --------------------------------------------------------------------------------
# Raw Name: $10 OFF | Happy Family (Midtown)
# Coupon: $11.5 off $40 rookie coupon
# Rating: 4.0
# Raw Delivery Info: 57-67min • Delivery $4.49 • average $39 • Chinese
# --------------------------------------------------------------------------------
# Raw Name: Abaya Thai (Midtown)
# Coupon: $11.5 off $40 rookie coupon
# Rating: 4.0
# Raw Delivery Info: 60-70min • Delivery $4.49 • Asian / Thai
# --------------------------------------------------------------------------------
# Raw Name: $12 OFF | OBAO (Midtown)
# Coupon: $11.5 off $40 rookie coupon
# Rating: No Rating
# Raw Delivery Info: Over 73min • Delivery $4.49 • average $17 • Asian / Vietnamese
# --------------------------------------------------------------------------------
# Raw Name: HEYTEA (Herald Square)
# Coupon: $11.5 off $40 rookie coupon
# Rating: No Rating
# Raw Delivery Info: 42-52min • Delivery $4.49 • average $10 • Bubble Tea
# --------------------------------------------------------------------------------
# Raw Name: $12 OFF | Taste Kitchen (Midtown)
# Coupon: Specials 100% off
# Rating: 4.3
# Raw Delivery Info: 60-70min • Delivery $4.49 • average $19 • Chinese
# --------------------------------------------------------------------------------
# Raw Name: $12 OFF | Maguro Sushi (Midtown)
# Coupon: $11.5 off $40 rookie coupon
# Rating: No Rating
# Raw Delivery Info: Over 73min • Delivery $4.99 • average $24 • Japanese / Noodles
# --------------------------------------------------------------------------------
# Raw Name: Hokkaido Baked Cheese Tart (Midtown)
# Coupon: $11.5 off $40 rookie coupon
# Rating: 4.6
# Raw Delivery Info: Over 73min • Delivery $4.99 • average $17 • Cake / Dessert
# --------------------------------------------------------------------------------
# Raw Name: $12 OFF | Hokkaido Baked Cheese Tart (East village)
# Coupon: $11.5 off $40 rookie coupon
# Rating: 4.7
# Raw Delivery Info: Over 73min • Delivery $4.99 • average $13 • Cake / Dessert
# --------------------------------------------------------------------------------
# Raw Name: $12 OFF | XW Spicy Hot Pot (中城)
# Coupon: Specials 100% off
# Rating: 4.3
# Raw Delivery Info: Over 73min • Delivery $4.99 • average $25 • Chinese / Hot Pot
# --------------------------------------------------------------------------------
# Raw Name: $7 OFF | Burp Bowl Cafe (United Nation)
# Coupon: $11.5 off $40 rookie coupon
# Rating: 4.5
# Raw Delivery Info: 57-67min • Delivery $4.49 • average $16 • Chinese / Noodles
# --------------------------------------------------------------------------------
# Raw Name: Shanghai Dim Sum Garden (Midtown)
# Coupon: $11.5 off $40 rookie coupon
# Rating: 4.3
# Raw Delivery Info: 56-66min • Delivery $2.99 • average $27 • Chinese
# --------------------------------------------------------------------------------
# Raw Name: $13 OFF | AweSum DimSum (Midtown)
# Coupon: $11.5 off $40 rookie coupon
# Rating: 4.4
# Raw Delivery Info: 59-69min • Delivery $4.49 • average $23 • Chinese / Cantonese
# --------------------------------------------------------------------------------
# Raw Name: NomNam
# Coupon: $11.5 off $40 rookie coupon
# Rating: 4.0
# Raw Delivery Info: Over 73min • Delivery $4.99 • average $29 • Asian / Vietnamese
# --------------------------------------------------------------------------------
# Raw Name: $20 OFF | Clucker's Crispy Chicken (Midtown)
# Coupon: Specials 100% off
# Rating: 5.0
# Raw Delivery Info: Over 73min • Delivery $4.99 • Fast Food / Chinese
# --------------------------------------------------------------------------------
# Raw Name: BCD Tofu House (Midtown)
# Coupon: $11.5 off $40 rookie coupon
# Rating: 4.7
# Raw Delivery Info: Over 73min • Delivery $4.99 • Korean
# --------------------------------------------------------------------------------
# Raw Name: $13 OFF | Rice on Fire (East village)
# Coupon: $11.5 off $40 rookie coupon
# Rating: 4.6
# Raw Delivery Info: 62-72min • Delivery $4.99 • average $15 • Fast Food / Chinese
# --------------------------------------------------------------------------------
# Raw Name: Lisa's Dumpling (Midtown)
# Coupon: $11.5 off $40 rookie coupon
# Rating: No Rating
# Raw Delivery Info: Over 73min • Delivery $2.99 • average $27 • Chinese / Noodles
# --------------------------------------------------------------------------------
# Raw Name: Mi Chinese Kitchen
# Coupon: $11.5 off $40 rookie coupon
# Rating: No Rating
# Raw Delivery Info: Over 73min • Delivery $4.99 • Chinese
# --------------------------------------------------------------------------------
# Raw Name: $7 OFF | Hunan X (Midtown)
# Coupon: $11.5 off $40 rookie coupon
# Rating: 5.0
# Raw Delivery Info: Over 73min • Delivery $4.49 • average $29 • Chinese / Spicy
# --------------------------------------------------------------------------------
# Raw Name: $5 OFF | JOOY TEA SHOPPE (HELL'S KITCHEN) (Midtown)
# Coupon: $11.5 off $40 rookie coupon
# Rating: 4.6
# Raw Delivery Info: 57-67min • Delivery $2.99 • average $9 • Bubble Tea
# --------------------------------------------------------------------------------
# Raw Name: $12 OFF | Chili (New York)
# Coupon: $11.5 off $40 rookie coupon
# Rating: 5.0
# Raw Delivery Info: 62-72min • Delivery $4.49 • average $30 • Chinese
# --------------------------------------------------------------------------------
# Raw Name: Milano Market
# Coupon: $11.5 off $40 rookie coupon
# Rating: 5.0
# Raw Delivery Info: 42-52min • Delivery $2.49 • Western / Italian
# --------------------------------------------------------------------------------
# Raw Name: Lady M (Bryant Park)
# Coupon: $11.5 off $40 rookie coupon
# Rating: No Rating
# Raw Delivery Info: 60-70min • Delivery $4.49 • average $21 • Cake / Dessert
# --------------------------------------------------------------------------------
# Raw Name: Down Under Coffee (Midtown)
# Coupon: $11.5 off $40 rookie coupon
# Rating: 5.0
# Raw Delivery Info: 50-60min • Delivery $2.99 • average $10 • Cafe
# --------------------------------------------------------------------------------
# Raw Name: $20 OFF | Fushimi Food Court (Midtown)
# Coupon: $11.5 off $40 rookie coupon
# Rating: No Rating
# Raw Delivery Info: Over 73min • Delivery $4.99 • average $23 • Japanese / Noodles
# --------------------------------------------------------------------------------
# Raw Name: $6 OFF | Lucky Pot (Midtown)
# Coupon: $11.5 off $40 rookie coupon
# Rating: No Rating
# Raw Delivery Info: 60-70min • Delivery $4.49 • Chinese / Hot Pot
# --------------------------------------------------------------------------------
# Raw Name: $4 OFF | MYORI NYC
# Coupon: $11.5 off $40 rookie coupon
# Rating: 5.0
# Raw Delivery Info: Over 73min • Delivery $4.99 • Bubble Tea
# --------------------------------------------------------------------------------
# Raw Name: $6 OFF | One's Hotpot (Midtown)
# Coupon: $11.5 off $40 rookie coupon
# Rating: 4.1
# Raw Delivery Info: 60-70min • Delivery $4.49 • average $15 • Chinese / Hot Pot
# --------------------------------------------------------------------------------
# Raw Name: 40% OFF | DD soup dumpling (Mid town)
# Coupon: $11.5 off $40 rookie coupon
# Rating: 4.4
# Raw Delivery Info: 57-67min • Delivery $4.49 • Chinese
# --------------------------------------------------------------------------------
# Raw Name: $5 OFF | Sweetea (Midtown)
# Coupon: $11.5 off $40 rookie coupon
# Rating: 5.0
# Raw Delivery Info: Over 73min • Delivery $4.99 • average $11 • Bubble Tea / Cafe
# --------------------------------------------------------------------------------
# Raw Name: El Gallo Taqueria
# Coupon: $11.5 off $40 rookie coupon
# Rating: No Rating
# Raw Delivery Info: 33-43min • Delivery $1.99 • Mexican / Western
# --------------------------------------------------------------------------------
# Raw Name: Oasis Cafe
# Coupon: $11.5 off $40 rookie coupon
# Rating: 5.0
# Raw Delivery Info: 46-56min • Delivery $2.99 • average $11 • Cafe
# --------------------------------------------------------------------------------
# Raw Name: HAN BAT
# Coupon: $11.5 off $40 rookie coupon
# Rating: 5.0
# Raw Delivery Info: 62-72min • Delivery $4.49 • average $38 • Korean
# --------------------------------------------------------------------------------
# Raw Name: ROYCE' Chocolate (Bryant Park)
# Coupon: $11.5 off $40 rookie coupon
# Rating: 5.0
# Raw Delivery Info: 60-70min • Delivery $4.49 • Cake / Dessert
# --------------------------------------------------------------------------------
# Raw Name: Sweetgreen
# Coupon: $11.5 off $40 rookie coupon
# Rating: No Rating
# Raw Delivery Info: 30-40min • Delivery $1.99 • Healthy
# --------------------------------------------------------------------------------
# Raw Name: Taco Mahal - West Village
# Coupon: $11.5 off $40 rookie coupon
# Rating: No Rating
# Raw Delivery Info: Over 73min • Delivery $4.99 • Indian / Asian
# --------------------------------------------------------------------------------
# Raw Name: Pho87 Vietnamese Soup (Midtown)
# Coupon: $11.5 off $40 rookie coupon
# Rating: No Rating
# Raw Delivery Info: 56-66min • Delivery $2.99 • average $17 • Asian / Vietnamese
# --------------------------------------------------------------------------------
# Raw Name: Oki Ramen
# Coupon: $11.5 off $40 rookie coupon
# Rating: No Rating
# Raw Delivery Info: 59-69min • Delivery $4.49 • Japanese / Noodles
# --------------------------------------------------------------------------------
# Raw Name: The Milton
# Coupon: $11.5 off $40 rookie coupon
# Rating: No Rating
# Raw Delivery Info: 44-54min • Delivery $2.49 • Fast Food / Burgers
# --------------------------------------------------------------------------------
# Raw Name: Bo's Bagels
# Coupon: $11.5 off $40 rookie coupon
# Rating: No Rating
# Raw Delivery Info: 36-46min • Delivery $1.99 • Fast Food / Burgers
# --------------------------------------------------------------------------------
# Raw Name: Sao Mai Vietnamese Cuisine
# Coupon: $11.5 off $40 rookie coupon
# Rating: No Rating
# Raw Delivery Info: Over 73min • Delivery $4.99 • Asian / Vietnamese
# --------------------------------------------------------------------------------
# Raw Name: 100%OFF | Mucha NYC (Manhattan Midtown)
# Coupon: $11.5 off $40 rookie coupon
# Rating: No Rating
# Raw Delivery Info: Over 73min • Delivery $4.99 • Bubble Tea
# --------------------------------------------------------------------------------
# Raw Name: Amorino Gelato (Manhattan Midtown)
# Coupon: $11.5 off $40 rookie coupon
# Rating: No Rating
# Raw Delivery Info: 56-66min • Delivery $2.99 • average $17 • Ice Cream / Dessert
# --------------------------------------------------------------------------------
# Raw Name: Make My Fish
# Coupon: $11.5 off $40 rookie coupon
# Rating: No Rating
# Raw Delivery Info: 37-47min • Delivery $1.99 • Fast Food / American
# --------------------------------------------------------------------------------
# Raw Name: $20 OFF | Quality Bento Box (Midtown)
# Coupon: $11.5 off $40 rookie coupon
# Rating: No Rating
# Raw Delivery Info: Over 73min • Delivery $4.99
# --------------------------------------------------------------------------------
# Raw Name: Tulcimexico Restaurant
# Coupon: $11.5 off $40 rookie coupon
# Rating: No Rating
# Raw Delivery Info: 53-63min • Delivery $2.99 • Mexican / Western
# --------------------------------------------------------------------------------
# Raw Name: 35% OFF | Orange Orange (Midtown)
# Coupon: $11.5 off $40 rookie coupon
# Rating: No Rating
# Raw Delivery Info: 61-71min • Delivery $4.49 • Chinese / Asian
# --------------------------------------------------------------------------------
# Raw Name: The Hummus And Pita Co (E 86th St)
# Coupon: $11.5 off $40 rookie coupon
# Rating: No Rating
# Raw Delivery Info: 43-53min • Delivery $2.49 • Mediterranean / Western
# --------------------------------------------------------------------------------
# Raw Name: Tidal Tea
# Coupon: $11.5 off $40 rookie coupon
# Rating: No Rating
# Raw Delivery Info: 43-53min • Delivery $2.49 • Bubble Tea
# --------------------------------------------------------------------------------
# Raw Name: Poke Bowl
# Coupon: $11.5 off $40 rookie coupon
# Rating: No Rating
# Raw Delivery Info: Over 73min • Delivery $4.99 • Poke
# --------------------------------------------------------------------------------
# Raw Name: Harlem Bar-B-Q
# Coupon: $11.5 off $40 rookie coupon
# Rating: No Rating
# Raw Delivery Info: 40-50min • Delivery $2.49 • American / Western
# --------------------------------------------------------------------------------
# Raw Name: Sweetgreen
# Coupon: $11.5 off $40 rookie coupon
# Rating: No Rating
# Raw Delivery Info: 38-48min • Delivery $1.99 • Healthy
# --------------------------------------------------------------------------------
# Raw Name: Tacos Grand Central
# Coupon: $11.5 off $40 rookie coupon
# Rating: No Rating
# Raw Delivery Info: 63-73min • Delivery $4.49 • Mexican / Western
# --------------------------------------------------------------------------------
# Raw Name: All’antico Vinaio (Sullivan Street)
# Coupon: $11.5 off $40 rookie coupon
# Rating: No Rating
# Raw Delivery Info: Over 73min • Delivery $4.99 • Fast Food / Burgers
# --------------------------------------------------------------------------------
# Raw Name: Best Bagel & Coffee
# Coupon: $11.5 off $40 rookie coupon
# Rating: No Rating
# Raw Delivery Info: 61-71min • Delivery $4.49 • Bubble Tea
# --------------------------------------------------------------------------------
# Raw Name: The Smith - East Village
# Coupon: $11.5 off $40 rookie coupon
# Rating: No Rating
# Raw Delivery Info: Over 73min • Delivery $4.99 • Fast Food / Burgers
# --------------------------------------------------------------------------------
# Raw Name: Kungfu Tea
# Coupon: $11.5 off $40 rookie coupon
# Rating: 5.0
# Raw Delivery Info: 37-47min • Delivery $4.49 • Bubble Tea / Cafe
# --------------------------------------------------------------------------------
# Raw Name: Burgermania (Midtown)
# Coupon: $11.5 off $40 rookie coupon
# Rating: No Rating
# Raw Delivery Info: 43-53min • Delivery $4.49 • Fast Food / Burgers
# --------------------------------------------------------------------------------
# Raw Name: Amorino Gelato (Manhattan Midtown)
# Coupon: $11.5 off $40 rookie coupon
# Rating: No Rating
# Raw Delivery Info: 32-42min • Delivery $2.49 • Ice Cream / Dessert
# --------------------------------------------------------------------------------
# Raw Name: Braddahs Hawaiian Bbq & Poke
# Coupon: $11.5 off $40 rookie coupon
# Rating: No Rating
# Raw Delivery Info: Over 73min • Delivery $4.99
# --------------------------------------------------------------------------------
# Raw Name: Bluestone Lane Coffee - 11 Madison
# Coupon: $11.5 off $40 rookie coupon
# Rating: No Rating
# Raw Delivery Info: Over 73min • Delivery $4.99 • Cafe / Bubble Tea
# --------------------------------------------------------------------------------
# Raw Name: $6 OFF | xinfutang
# Coupon: $11.5 off $40 rookie coupon
# Rating: 4.9
# Raw Delivery Info: Over 73min • Delivery $4.99 • average $11 • Bubble Tea
# --------------------------------------------------------------------------------
# Raw Name: Del Sur
# Coupon: $11.5 off $40 rookie coupon
# Rating: No Rating
# Raw Delivery Info: 61-71min • Delivery $4.49 • Mexican / Western
# --------------------------------------------------------------------------------
# Raw Name: BCD Tofu House (Midtown)
# Coupon: $11.5 off $40 rookie coupon
# Rating: 5.0
# Raw Delivery Info: Over 73min • Delivery $4.99 • average $30 • Korean
# --------------------------------------------------------------------------------
# Raw Name: i taste Express
# Coupon: $11.5 off $40 rookie coupon
# Rating: No Rating
# Raw Delivery Info: Over 73min • Delivery $4.99 • Chinese
# --------------------------------------------------------------------------------
# Raw Name: Yakiniku Futago·Japanese BBQ&Wagyu (New York)
# Coupon: $11.5 off $40 rookie coupon
# Rating: No Rating
# Raw Delivery Info: Over 73min • Delivery $4.99 • Japanese / BBQ
# --------------------------------------------------------------------------------
# Raw Name: $7 OFF | Jiang’s Kitchen (East Village)
# Coupon: $11.5 off $40 rookie coupon
# Rating: 4.0
# Raw Delivery Info: Over 73min • Delivery $4.99 • average $30 • Chinese
# --------------------------------------------------------------------------------
# Raw Name: The Halal Guys (14th Street, Ny)
# Coupon: $11.5 off $40 rookie coupon
# Rating: No Rating
# Raw Delivery Info: Over 73min • Delivery $4.99
# --------------------------------------------------------------------------------
# Raw Name: Tappo NycThinCrust Pizza - Flatiron
# Coupon: $11.5 off $40 rookie coupon
# Rating: No Rating
# Raw Delivery Info: Over 73min • Delivery $4.99 • Western / Italian
# --------------------------------------------------------------------------------
# Raw Name: Simò Pizza - Meatpacking
# Coupon: $11.5 off $40 rookie coupon
# Rating: No Rating
# Raw Delivery Info: Over 73min • Delivery $4.99 • Fast Food / Pizza
# --------------------------------------------------------------------------------
# Raw Name: Dos Caminos - Meat Packing
# Coupon: $11.5 off $40 rookie coupon
# Rating: No Rating
# Raw Delivery Info: Over 73min • Delivery $4.99 • Mexican / Western
# --------------------------------------------------------------------------------
# Raw Name: 5ive Spice Les
# Coupon: $11.5 off $40 rookie coupon
# Rating: No Rating
# Raw Delivery Info: Over 73min • Delivery $6.99 • Asian / Vietnamese
# --------------------------------------------------------------------------------
# Raw Name: Sweet Rehab
# Coupon: $11.5 off $40 rookie coupon
# Rating: No Rating
# Raw Delivery Info: Over 73min • Delivery $6.99 • Bubble Tea
# --------------------------------------------------------------------------------
# Raw Name: $10 OFF | U Look Delicious Snacks (Midtown)
# Coupon: Get $15
# Rating: 5.0
# Raw Delivery Info: 61-71min • Delivery $4.99 • Grocery / Convenience
# --------------------------------------------------------------------------------
# Raw Name: Flor de mayo Food (Midtown)
# Coupon: No Coupon
# Rating: No Rating
# Raw Delivery Info: 58-68min • Delivery $4.49 • Chinese / Asian
# --------------------------------------------------------------------------------
# Raw Name: $12 OFF | Chihiro Tea (Downtown)
# Coupon: $11.5 off $40 rookie coupon
# Rating: 4.9
# Raw Delivery Info: Over 73min • Delivery $4.99 • average $9 • Bubble Tea / Cafe
# --------------------------------------------------------------------------------
# Raw Name: $12 OFF | To Eat Sushi (Downtown)
# Coupon: $11.5 off $40 rookie coupon
# Rating: 4.6
# Raw Delivery Info: Over 73min • Delivery $4.99 • average $22 • Japanese
# --------------------------------------------------------------------------------
# Raw Name: SHINY TEA (Uptown)
# Coupon: $11.5 off $40 rookie coupon
# Rating: 5.0
# Raw Delivery Info: 33-43min • Delivery $1.99 • average $6 • Bubble Tea
# --------------------------------------------------------------------------------
# Raw Name: $7 OFF | Moge Tee ( Uptown)
# Coupon: $11.5 off $40 rookie coupon
# Rating: 4.7
# Raw Delivery Info: 25-40min • Delivery $1.99 • average $6 • Bubble Tea / Ice Cream
# --------------------------------------------------------------------------------
# Raw Name: Chow House (downtown)
# Coupon: $11.5 off $40 rookie coupon
# Rating: 4.4
# Raw Delivery Info: Over 73min • Delivery $4.99 • average $28 • Chinese / Spicy
# --------------------------------------------------------------------------------
# Raw Name: 满$6减$6 | Anjelly (Downtown)
# Coupon: $11.5 off $40 rookie coupon
# Rating: No Rating
# Raw Delivery Info: Over 73min • Delivery $4.99 • average $16 • Bubble Tea / Cafe
# --------------------------------------------------------------------------------
# Raw Name: Tora Tea NYC (NYU)
# Coupon: $11.5 off $40 rookie coupon
# Rating: No Rating
# Raw Delivery Info: Over 73min • Delivery $4.99 • Bubble Tea
# --------------------------------------------------------------------------------
# Raw Name: $13 OFF | De Zhuang Hot Pot, Sautéed Chili Dishes (East village)
# Coupon: Specials 100% off
# Rating: No Rating
# Raw Delivery Info: Over 73min • Delivery $4.99 • average $16 • Fast Food / Spicy
# --------------------------------------------------------------------------------
# Raw Name: Soho Sushi (Downtown )
# Coupon: $11.5 off $40 rookie coupon
# Rating: No Rating
# Raw Delivery Info: Over 73min • Delivery $4.99 • average $38 • Japanese
# --------------------------------------------------------------------------------
# Raw Name: her boba (Midtown)
# Coupon: $11.5 off $40 rookie coupon
# Rating: 5.0
# Raw Delivery Info: 32-42min • Delivery $2.99 • average $15 • Bubble Tea
# --------------------------------------------------------------------------------
# Raw Name: $6 OFF | PH 66 (Manhattan)
# Coupon: Specials 100% off
# Rating: No Rating
# Raw Delivery Info: Over 73min • Delivery $4.99 • average $21 • Asian / Vietnamese
# --------------------------------------------------------------------------------
# Raw Name: MoomooChaa (Downtown)
# Coupon: $11.5 off $40 rookie coupon
# Rating: 4.6
# Raw Delivery Info: Over 73min • Delivery $4.99 • Bubble Tea
# --------------------------------------------------------------------------------
# Raw Name: $10 OFF | CheLi Manhattan (Downtown)
# Coupon: $11.5 off $40 rookie coupon
# Rating: 4.5
# Raw Delivery Info: Over 73min • Delivery $4.99 • average $40 • Chinese
# --------------------------------------------------------------------------------
# Raw Name: $13 OFF | China Flame (East village)
# Coupon: Specials 100% off
# Rating: No Rating
# Raw Delivery Info: Over 73min • Delivery $4.99 • average $26 • Chinese / Spicy
# --------------------------------------------------------------------------------
# Raw Name: $6 OFF | Tbaar-Time Square (Midtown)
# Coupon: $11.5 off $40 rookie coupon
# Rating: 4.1
# Raw Delivery Info: 56-66min • Delivery $2.99 • average $14 • Bubble Tea / Cafe
# --------------------------------------------------------------------------------
# Raw Name: 35% OFF | Dumplings N Dips (East Village)
# Coupon: $11.5 off $40 rookie coupon
# Rating: No Rating
# Raw Delivery Info: Over 73min • Delivery $4.99 • Chinese / Noodles
# --------------------------------------------------------------------------------
# Raw Name: Misoya (Downtown)
# Coupon: $11.5 off $40 rookie coupon
# Rating: 5.0
# Raw Delivery Info: Over 73min • Delivery $4.99 • average $30 • Japanese / Noodles
# --------------------------------------------------------------------------------
# Raw Name: $7 OFF | Möge Tee (East Village)
# Coupon: $11.5 off $40 rookie coupon
# Rating: 4.8
# Raw Delivery Info: Over 73min • Delivery $4.99 • average $8 • Bubble Tea
# --------------------------------------------------------------------------------
# Raw Name: $4.5 OFF | Meet Fresh (Downtown)
# Coupon: $11.5 off $40 rookie coupon
# Rating: 4.4
# Raw Delivery Info: Over 73min • Delivery $4.99 • average $17 • Bubble Tea / Dessert
# --------------------------------------------------------------------------------
# Raw Name: Thai Market
# Coupon: $11.5 off $40 rookie coupon
# Rating: No Rating
# Raw Delivery Info: 25-40min • Delivery $1.99 • average $21 • Asian / Thai
# --------------------------------------------------------------------------------
# Raw Name: $12 OFF | Mi Tea (East Village )
# Coupon: $11.5 off $40 rookie coupon
# Rating: 4.8
# Raw Delivery Info: Over 73min • Delivery $4.99 • average $4 • Bubble Tea
# --------------------------------------------------------------------------------
# Raw Name: $10 OFF | Joe's Steam Rice Roll (Manhattan Uptown)
# Coupon: Specials 20% off
# Rating: 4.6
# Raw Delivery Info: 44-54min • Delivery $1.99 • average $14 • Fast Food / Breakfast
# --------------------------------------------------------------------------------
# Raw Name: $7 OFF | Ando patisseie (Downtown)
# Coupon: $11.5 off $40 rookie coupon
# Rating: 4.8
# Raw Delivery Info: Over 73min • Delivery $4.99 • average $21 • Cake / Dessert
# --------------------------------------------------------------------------------
# Raw Name: $15 OFF | Dim Sum Bloom
# Coupon: Specials 60% off
# Rating: 4.8
# Raw Delivery Info: 37-47min • Delivery $1.99 • average $16 • Chinese
# --------------------------------------------------------------------------------
# Raw Name: East Village | Koko Wings & Cajun Seafoods
# Coupon: $11.5 off $40 rookie coupon
# Rating: No Rating
# Raw Delivery Info: Over 73min • Delivery $4.99 • Fast Food / Chinese
# --------------------------------------------------------------------------------
# Raw Name: Soft Sweve (Kips Bay) (Manhattan)
# Coupon: $11.5 off $40 rookie coupon
# Rating: 4.0
# Raw Delivery Info: Over 73min • Delivery $4.99 • Ice Cream / Dessert
# --------------------------------------------------------------------------------
# Raw Name: ZlS BBQ (Manhattan)
# Coupon: $11.5 off $40 rookie coupon
# Rating: No Rating
# Raw Delivery Info: Over 73min • Delivery $4.99 • average $35 • Chinese / BBQ
# --------------------------------------------------------------------------------
# Raw Name: Save$5 | Smoove Ice Cream (Downtown)
# Coupon: $11.5 off $40 rookie coupon
# Rating: 5.0
# Raw Delivery Info: Over 73min • Delivery $6.99 • Ice Cream / Dessert
# --------------------------------------------------------------------------------
# Raw Name: $12 OFF | Wang Lao Ji (Downtown)
# Coupon: $11.5 off $40 rookie coupon
# Rating: No Rating
# Raw Delivery Info: Over 73min • Delivery $6.99 • Bubble Tea
# --------------------------------------------------------------------------------
# Raw Name: The Dough Club (Downtown)
# Coupon: $11.5 off $40 rookie coupon
# Rating: No Rating
# Raw Delivery Info: Over 73min • Delivery $6.99 • Cake / Dessert
# --------------------------------------------------------------------------------
# Raw Name: Soft Swerve (Allen St) (Manhattan)
# Coupon: $11.5 off $40 rookie coupon
# Rating: 4.2
# Raw Delivery Info: Over 73min • Delivery $6.99 • Ice Cream / Dessert
# --------------------------------------------------------------------------------
# Raw Name: $6 OFF | BBF いざかや (Downtown)
# Coupon: $11.5 off $40 rookie coupon
# Rating: No Rating
# Raw Delivery Info: Over 73min • Delivery $6.99 • Japanese / BBQ
# --------------------------------------------------------------------------------
# Raw Name: BOGO | Matcha Cafe Maiko (Chinatown)
# Coupon: $11.5 off $40 rookie coupon
# Rating: 4.2
# Raw Delivery Info: Over 73min • Delivery $6.99 • average $10 • Bubble Tea / Dessert
# --------------------------------------------------------------------------------
# Raw Name: $12 OFF | Yo Sushi (Chinatown)
# Coupon: Specials 50% off
# Rating: 4.0
# Raw Delivery Info: Over 73min • Delivery $6.99 • average $22 • Japanese
# --------------------------------------------------------------------------------
# Raw Name: $12 OFF | Cloud Vietnamese Restaurant
# Coupon: $11.5 off $40 rookie coupon
# Rating: 4.2
# Raw Delivery Info: Over 73min • Delivery $6.99 • Asian / Vietnamese
# --------------------------------------------------------------------------------
# Raw Name: $5 OFF | Vivi Bubble Tea (Chinatown)
# Coupon: $11.5 off $40 rookie coupon
# Rating: 4.6
# Raw Delivery Info: Over 73min • Delivery $8.99 • average $11 • Bubble Tea
# --------------------------------------------------------------------------------
# Raw Name: $7 OFF | Da Long Yi Hotpot (Chinatown)
# Coupon: $11.5 off $40 rookie coupon
# Rating: 4.5
# Raw Delivery Info: Over 73min • Delivery $8.99 • average $28 • Fast Food / Spicy
# --------------------------------------------------------------------------------
# Raw Name: $4.5 OFF | Yi Fang Taiwan Fruit Tea
# Coupon: $11.5 off $40 rookie coupon
# Rating: 4.5
# Raw Delivery Info: Over 73min • Delivery $8.99 • average $6 • Bubble Tea
# --------------------------------------------------------------------------------
# Raw Name: $9 OFF | Peking Duck House (Chinatown)
# Coupon: Specials 5% off
# Rating: 4.7
# Raw Delivery Info: Over 73min • Delivery $8.99 • average $9 • Chinese
# --------------------------------------------------------------------------------
# Raw Name: $4.5 OFF | Mango Mango (Chinatown)
# Coupon: $11.5 off $40 rookie coupon
# Rating: 4.5
# Raw Delivery Info: Over 73min • Delivery $8.99 • average $13 • Bubble Tea / Cake
# --------------------------------------------------------------------------------
# Raw Name: 30% OFF | JM BBQ (Manhattan Downtown)
# Coupon: $11.5 off $40 rookie coupon
# Rating: 4.0
# Raw Delivery Info: Over 73min • Delivery $8.99 • average $29 • Chinese / BBQ
# --------------------------------------------------------------------------------
# Raw Name: $4.5 OFF | Suga Box (Chinatown)
# Coupon: $11.5 off $40 rookie coupon
# Rating: 4.5
# Raw Delivery Info: Over 73min • Delivery $8.99 • average $9 • Bubble Tea / Ice Cream
# --------------------------------------------------------------------------------
# Raw Name: $13 OFF | Just Mala Pot (Chinatown)
# Coupon: $11.5 off $40 rookie coupon
# Rating: 4.3
# Raw Delivery Info: Over 73min • Delivery $8.99 • average $14 • Chinese / Hot Pot
# --------------------------------------------------------------------------------
# Raw Name: $13 OFF | Atlas Kitchen (Manhattan Uptown)
# Coupon: $11.5 off $40 rookie coupon
# Rating: 4.5
# Raw Delivery Info: 25-40min • Delivery $1.99 • average $25 • Chinese / Spicy
# --------------------------------------------------------------------------------
# Raw Name: $8 OFF | Kyuramen (UPTOWN)
# Coupon: Specials 50% off
# Rating: 4.9
# Raw Delivery Info: 26-36min • Delivery $1.99 • average $23 • Japanese / Noodles
# --------------------------------------------------------------------------------
# Raw Name: $25-$13 | Happy Hot Hunan (Uptown)
# Coupon: $11.5 off $40 rookie coupon
# Rating: 4.5
# Raw Delivery Info: 26-36min • Delivery $1.99 • average $22 • Chinese / Spicy
# --------------------------------------------------------------------------------
# Raw Name: $10 OFF | Dun Huang (Manhattan Uptown)
# Coupon: $11.5 off $40 rookie coupon
# Rating: 4.6
# Raw Delivery Info: 31-41min • Delivery $1.99 • average $24 • Chinese / Noodles
# --------------------------------------------------------------------------------
# Raw Name: $5 OFF | Sing Choi Kee (Downtown)
# Coupon: Everything 30% off
# Rating: 4.8
# Raw Delivery Info: Over 73min • Delivery $4.99 • average $18 • Chinese
# --------------------------------------------------------------------------------
# Raw Name: $10 OFF | AweSum DimSum (Downtown)
# Coupon: $11.5 off $40 rookie coupon
# Rating: 4.8
# Raw Delivery Info: 53-63min • Delivery $4.99 • average $22 • Dessert / Chinese
# --------------------------------------------------------------------------------
# Raw Name: $6 OFF | Yi Fang Taiwan Fruit Tea (Lexington)
# Coupon: $11.5 off $40 rookie coupon
# Rating: 4.8
# Raw Delivery Info: Over 73min • Delivery $4.99 • average $13 • Bubble Tea
# --------------------------------------------------------------------------------
# Raw Name: $13 OFF | Bings and Noodle (downtown)
# Coupon: $11.5 off $40 rookie coupon
# Rating: 4.8
# Raw Delivery Info: 53-63min • Delivery $4.99 • average $18 • Fast Food / Chinese
# --------------------------------------------------------------------------------
# Raw Name: $13 OFF | Ajisen Rammen (Midtown)
# Coupon: $11.5 off $40 rookie coupon
# Rating: 4.7
# Raw Delivery Info: Over 73min • Delivery $4.99 • average $15 • Japanese / Noodles
# --------------------------------------------------------------------------------
# Raw Name: $7 OFF | Mountain House Manhattan (Downtown)
# Coupon: $11.5 off $40 rookie coupon
# Rating: 4.5
# Raw Delivery Info: Over 73min • Delivery $4.99 • average $39 • Chinese / Spicy
# --------------------------------------------------------------------------------
# Raw Name: $7 OFF | 108 Food Dried Hot Pot (Uptown)
# Coupon: Specials 77% off
# Rating: 4.4
# Raw Delivery Info: 25-40min • Delivery $1.99 • average $32 • Chinese / Spicy
# --------------------------------------------------------------------------------
# Raw Name: $7 OFF | Debutea Peach Summer (NYU)
# Coupon: $11.5 off $40 rookie coupon
# Rating: 4.6
# Raw Delivery Info: Over 73min • Delivery $4.99 • average $9 • Bubble Tea
# --------------------------------------------------------------------------------

# %%
import pandas as pd

# Load raw data into a DataFrame
df = pd.DataFrame(restaurant_data)

# Extract the clean name and location from `raw_name`
df[["Name", "Location"]] = df["raw_name"].str.extract(r"^(?:.*\|\s)?(.+?)\s\((.+?)\)$")

# Extract the delivery time, fee, average price, and food type from `raw_delivery_info`
df["Delivery Time"] = df["raw_delivery_info"].str.extract(r"(\d+-\d+min|Over \d+min)")
df["Delivery Fee"] = df["raw_delivery_info"].str.extract(r"Delivery \$([\d.]+)").fillna("") # check this .fillna("")
df["Average Price"] = df["raw_delivery_info"].str.extract(r"average \$([\d.]+)").fillna("")
df["Food Type"] = df["raw_delivery_info"].str.extract(r"•\s([\w\s]+)$")

# Add a dollar sign to Delivery Fee and Average Price
df["Delivery Fee"] = df["Delivery Fee"].apply(lambda x: f"${x}" if x else "")
df["Average Price"] = df["Average Price"].apply(lambda x: f"${x}" if x else "")

# Drop the raw fields if no longer needed
df = df.drop(columns=["raw_name", "raw_delivery_info"])

# Display the DataFrame
print(df)

# Save the data to CSV
df.to_csv("fantuan_data.csv", index=False)
# Out:
#                           Coupon Rating                         Name  \
# 0    $11.5 off $40 rookie coupon    4.7                Shanghai Time
# 1    $11.5 off $40 rookie coupon    4.7  Tasty Hand-Pulled Noodles 2
# 2              Specials 100% off    4.4                      Hutaoli
# 3    $11.5 off $40 rookie coupon    4.8                       HEYTEA
# 4              Specials 100% off    4.7             The Best Sichuan
# ..                           ...    ...                          ...
# 184  $11.5 off $40 rookie coupon    4.8             Bings and Noodle
# 185  $11.5 off $40 rookie coupon    4.7                Ajisen Rammen
# 186  $11.5 off $40 rookie coupon    4.5     Mountain House Manhattan
# 187             Specials 77% off    4.4       108 Food Dried Hot Pot
# 188  $11.5 off $40 rookie coupon    4.6         Debutea Peach Summer
#
#      Location Delivery Time Delivery Fee Average Price   Food Type
# 0     Midtown    Over 73min        $4.49           $23     Chinese
# 1     Midtown      49-59min        $2.99           $25         NaN
# 2     Midtown      62-72min        $4.49                       NaN
# 3    Broadway      60-70min        $4.49            $9  Bubble Tea
# 4     Midtown      42-52min        $4.49           $24         NaN
# ..        ...           ...          ...           ...         ...
# 184  downtown      53-63min        $4.99           $18         NaN
# 185   Midtown    Over 73min        $4.99           $15         NaN
# 186  Downtown    Over 73min        $4.99           $39         NaN
# 187    Uptown      25-40min        $1.99           $32         NaN
# 188       NYU    Over 73min        $4.99            $9  Bubble Tea
#
# [189 rows x 8 columns]
